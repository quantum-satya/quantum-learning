# %% [markdown]
# # 📝 Jupyter Markdown Formatting Cheatsheet
#
# ## ✅ 1. Simple Text
# Just type normally:
# This is plain text in a markdown cell.
#
# ---
#
# ## ✅ 2. Bold, Italic, Underline
#
# - **Bold**: `**bold**` → **bold**
# - *Italic*: `*italic*` → *italic*
# - ***Bold Italic***: `***bold italic***` → ***bold italic***
# - <u>Underline</u>: `<u>text</u>` → <u>Underline</u>
#
# ---
#
# ## ✅ 3. Headings
#
# ```markdown
# # Heading 1
# ## Heading 2
# ### Heading 3
# ```
#
# ---
#
# ## ✅ 4. Lists
#
# - Bullet List
#   - Sub-item
#
# 1. Numbered Item
# 2. Another item
#
# ---
#
# ## ✅ 5. Colored Text (HTML)
#
# - <span style="color:green">Green Text</span>
# - <span style="color:red">Red Text</span>
# - <span style="color:blue; font-weight:bold">Bold Blue</span>
#
# ---
#
# ## ✅ 6. Code & Equations
#
# ### Inline code: `print("Hello")`
#
# ### Code Block:
# ```python
# def greet():
#     print("Hello Satya")
# ```
#
# ### LaTeX Math:
# Einstein’s equation: $E = mc^2$
#
# $$\psi(x) = A \sin(kx - \omega t)$$
#
# ---
#
# ## ✅ 7. Horizontal Line
#
# ```
# ---
# ```
#
# ---

# %% [markdown]
# ## ✅ 8. New Lines in Markdown
#
# ### 🔹 Paragraph Break (Blank Line Between)
# ```markdown
# This is the first paragraph.
#
# This is the second paragraph.
# ```
# ➡️ Output:
# This is the first paragraph.
#
# This is the second paragraph.
#
# ---
#
# ### 🔹 Line Break (Without Paragraph Break)
# Use **two spaces at the end of the line** or an HTML `<br>` tag.
#
# ```markdown
# This is line one with two spaces at the end.
# This will appear directly below.
#
# This is another way using <br> tag.<br>
# Line below is tight.
# ```
# ➡️ Output:
# This is line one with two spaces at the end.
# This will appear directly below.
#
# This is another way using <br> tag.<br>
# Line below is tight.
