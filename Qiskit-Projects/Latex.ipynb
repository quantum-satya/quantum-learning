# %% [markdown]
# **LaTeX Cheat Sheet for Quantum Computing & Linear Algebra (Jupyter-ready)**
#
# ---
#
# ### 🌌 Basic Math Formatting (Jupyter Markdown Cells)
#
# Wrap all math in `$ ... $` for inline or `$$ ... $$` for display-style.
#
# ```latex
# Inline: $a^2 + b^2 = c^2$
# Display:
# $$
# a^2 + b^2 = c^2
# $$
# ```
#
# ---
#
# ### α Greek Letters
#
# ```latex
# \alpha, \beta, \gamma, \delta, \epsilon
# \theta, \phi, \psi, \omega, \lambda
# ```
#
# Example:
#
# ```latex
# $\psi = \alpha |0\rangle + \beta |1\rangle$
# ```
#
# ---
#
# ### ⎚ Dirac Notation (Bra-Ket)
#
# ```latex
# |0\rangle  \quad  |1\rangle  \quad  \langle 0|  \quad  \langle \psi| \phi \rangle
# ```
#
# Example:
#
# ```latex
# $|\psi\rangle = \alpha |0\rangle + \beta |1\rangle$
# ```
#
# ---
#
# ### ✎ Matrices & Vectors
#
# ```latex
# \begin{bmatrix} a & b \\ c & d \end{bmatrix}
# \begin{pmatrix} a \\ b \\ c \end{pmatrix}
# ```
#
# Example:
#
# ```latex
# $\begin{bmatrix} 0 & 1 \\ 1 & 0 \end{bmatrix}$
# ```
#
# ---
#
# ### ℵ Operators & Symbols
#
# ```latex
# \otimes = Tensor product
# \cdot = Dot product
# \times = Cross product
# \leq, \geq = ≤, ≥
# \pm = ±
# \approx = ≈
# \neq = ≠
# ```
#
# ---
#
# ### ✲ Special Quantum Examples
#
# **Bell inequality**
#
# ```latex
# $|\langle AB \rangle - \langle Ab \rangle + \langle aB \rangle + \langle ab \rangle| \leq 2$
# ```
#
# **Pauli Operators**
#
# ```latex
# $X = \begin{bmatrix} 0 & 1 \\ 1 & 0 \end{bmatrix}$
# $Z = \begin{bmatrix} 1 & 0 \\ 0 & -1 \end{bmatrix}$
# ```
#
# **Eigenstate Equation**
#
# ```latex
# $H |\psi\rangle = E |\psi\rangle$
# ```
#
# ---
#
# ### ✍ Tips
#
# * Use `\quad` for spacing.
# * Use `\text{}` inside math to write plain text: `$E = mc^2,\ \text{where}\ c=3\times10^8$`
# * In Jupyter, **Markdown Cell ✔**, not code cell.
#
# ---
#
# ✅ You can copy and paste this cheat sheet into a `.md` (Markdown) file and view it on GitHub or in Jupyter Notebooks.
#
# Let me know if you'd like this exported as `.pdf` or included in your GitHub repo directly!
